# %% [markdown]
# <a href="https://colab.research.google.com/github/mounika7600/Mobile_price_range_prediction/blob/master/mobile_price_range.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv('mobile_price_range_data.csv')

# %%
dataset.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
dataset.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...

# %%
#internal memory vs price range
sns.pointplot(y = 'int_memory',x = 'price_range',data=dataset)

# %%
#ram vs price range
sns.jointplot(x = 'ram' , y = 'price_range' , data = dataset , color ='blue',kind='kde')

# %%
#battey power vs price range
sns.boxplot(x='price_range',y='battery_power',data=dataset)

# %%
#checking null values
dataset.isna().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# Logistic Regression

# %%
x_tr,x_te,y_tr,y_te = train_test_split(x,y,test_size=0.25)
print(x_tr.shape)
print(x_te.shape)
print(y_tr.shape)
print(y_te.shape)
# Out:
# (1500, 20)
# (500, 20)
# (1500,)
# (500,)

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %%
cm = confusion_matrix(y_te,ypred)
print(cm)
print(classification_report(y_te,ypred))
# Out:
# [[103  23   1   0]
#  [ 27  71  28   5]
#  [  0  26  58  40]
#  [  0   1  29  88]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.81      0.80       127
#            1       0.59      0.54      0.56       131
#            2       0.50      0.47      0.48       124
#            3       0.66      0.75      0.70       118
#
#     accuracy                           0.64       500
#    macro avg       0.64      0.64      0.64       500
# weighted avg       0.64      0.64      0.64       500

# %%
corr_mat=dataset.corr()
plt.figure(figsize=(20,20))
sns.heatmap(corr_mat,annot=True)

# %%
x=dataset.iloc[:,:-1].values
y=dataset.iloc[:,-1].values

# %%
x[0]
# Out:
# array([8.420e+02, 0.000e+00, 2.200e+00, 0.000e+00, 1.000e+00, 0.000e+00,
#        7.000e+00, 6.000e-01, 1.880e+02, 2.000e+00, 2.000e+00, 2.000e+01,
#        7.560e+02, 2.549e+03, 9.000e+00, 7.000e+00, 1.900e+01, 0.000e+00,
#        0.000e+00, 1.000e+00])

# %%
y[0]
# Out:
# 1

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=0)

# %%
x_train.shape
# Out:
# (1500, 20)

# %%
x_test.shape
# Out:
# (500, 20)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
from sklearn.ensemble import RandomForestClassifier
classifier1 = RandomForestClassifier(n_estimators = 15,criterion = 'entropy') 
classifier1.fit(x_train,y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=15)

# %%
y_pred1=classifier1.predict(x_test)

# %%
y_pred1
# Out:
# array([3, 0, 2, 1, 2, 0, 0, 2, 3, 1, 0, 3, 0, 2, 3, 0, 3, 2, 2, 1, 0, 0,
#        3, 1, 1, 2, 3, 1, 3, 1, 1, 0, 1, 0, 2, 3, 0, 0, 3, 3, 3, 1, 3, 2,
#        1, 3, 0, 1, 3, 1, 1, 3, 0, 3, 0, 2, 2, 2, 0, 3, 3, 1, 2, 2, 1, 2,
#        3, 3, 2, 2, 3, 2, 1, 0, 1, 3, 2, 2, 2, 2, 3, 3, 2, 0, 0, 0, 2, 1,
#        2, 3, 1, 2, 2, 0, 0, 3, 3, 3, 0, 3, 1, 1, 2, 1, 3, 2, 2, 3, 2, 3,
#        2, 0, 0, 1, 2, 2, 0, 1, 1, 0, 0, 3, 2, 2, 1, 2, 1, 1, 0, 2, 1, 3,
#        3, 3, 3, 3, 3, 1, 0, 1, 1, 2, 1, 3, 0, 3, 0, 0, 2, 0, 1, 1, 1, 1,
#        3, 0, 0, 3, 1, 3, 2, 1, 3, 1, 3, 3, 3, 2, 1, 0, 3, 2, 2, 3, 3, 0,
#        1, 2, 3, 0, 2, 1, 0, 1, 2, 1, 2, 0, 2, 3, 1, 1, 0, 2, 3, 0, 1, 3,
#        1, 0, 3, 3, 3, 1, 1, 3, 3, 2, 1, 0, 0, 2, 3, 3, 0, 0, 1, 3, 2, 3,
#        3, 3, 0, 0, 2, 2, 3, 2, 0, 2, 0, 0, 0, 3, 3, 1, 2, 2, 0, 1, 0, 2,
#        3, 3, 0, 0, 1, 3, 3, 1, 3, 0, 3, 1, 1, 0, 1, 3, 3, 2, 0, 0, 1, 2,
#        3, 2, 2, 3, 2, 1, 0, 3, 3, 1, 1, 3, 2, 2, 2, 1, 0, 2, 1, 2, 0, 0,
# ...

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred1)
sns.heatmap(cm, annot=True)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred1)
# Out:
# 0.83

# %% [markdown]
# KNN ALGORITHM

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier2 = KNeighborsClassifier(n_neighbors=39,metric = 'minkowski')
classifier2.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=39)

# %%
y_pred2=classifier2.predict(x_test)

# %%
y_pred2
# Out:
# array([3, 0, 2, 1, 1, 0, 0, 2, 3, 0, 1, 3, 1, 2, 2, 1, 3, 2, 1, 0, 1, 0,
#        3, 2, 1, 2, 3, 2, 2, 0, 0, 0, 1, 0, 1, 3, 0, 1, 3, 3, 2, 2, 3, 2,
#        0, 3, 1, 2, 2, 1, 1, 2, 0, 3, 0, 2, 2, 2, 0, 2, 2, 1, 1, 2, 2, 2,
#        2, 2, 2, 1, 3, 1, 1, 0, 2, 2, 2, 2, 2, 1, 2, 3, 2, 0, 1, 0, 2, 1,
#        1, 3, 1, 2, 1, 0, 2, 3, 3, 3, 0, 3, 0, 2, 2, 1, 2, 2, 2, 2, 2, 3,
#        2, 0, 0, 0, 1, 1, 0, 0, 1, 0, 0, 3, 2, 2, 1, 2, 0, 1, 0, 3, 0, 3,
#        2, 3, 3, 3, 2, 1, 0, 1, 0, 2, 1, 2, 0, 3, 0, 0, 2, 0, 1, 1, 1, 0,
#        3, 1, 0, 3, 1, 2, 2, 0, 2, 2, 1, 3, 3, 1, 2, 0, 3, 1, 1, 3, 3, 0,
#        2, 1, 3, 1, 2, 2, 0, 1, 3, 1, 2, 0, 2, 3, 1, 1, 0, 2, 2, 0, 0, 2,
#        2, 0, 3, 3, 3, 1, 3, 3, 3, 3, 0, 0, 0, 2, 2, 3, 0, 0, 1, 2, 1, 3,
#        2, 3, 0, 0, 2, 3, 2, 0, 1, 1, 1, 1, 0, 3, 2, 1, 2, 1, 1, 1, 0, 2,
#        2, 3, 1, 0, 1, 3, 3, 1, 3, 0, 3, 1, 0, 0, 2, 3, 3, 1, 0, 1, 1, 1,
#        3, 1, 2, 2, 2, 1, 0, 2, 3, 2, 0, 3, 2, 3, 2, 1, 1, 2, 1, 1, 0, 0,
# ...

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred2)
# Out:
# 0.61
